# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram-Sivakumar2211/DAA-Exp-1/blob/main/DAA%20Exp%201-A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sorted roll numbers
arr = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# Roll number to search
key = 700


def interpolation_search(arr, key):
    low = 0
    high = len(arr) - 1
    probes = 0

    while low <= high and key >= arr[low] and key <= arr[high]:
        probes += 1

        if low == high:
            if arr[low] == key:
                return low, probes
            break

        pos = low + ((key - arr[low]) * (high - low)) // (arr[high] - arr[low])

        if arr[pos] == key:
            return pos, probes
        elif arr[pos] < key:
            low = pos + 1
        else:
            high = pos - 1

    return -1, probes


def binary_search(arr, key):
    low = 0
    high = len(arr) - 1
    probes = 0

    while low <= high:
        probes += 1

        mid = (low + high) // 2

        if arr[mid] == key:
            return mid, probes
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1

    return -1, probes


# Compare both searches
i_index, i_probes = interpolation_search(arr, key)
b_index, b_probes = binary_search(arr, key)

print("Interpolation Search:")
print("Index =", i_index)
print("Probes =", i_probes)

print("\nBinary Search:")
print("Index =", b_index)
print("Probes =", b_probes)
# Out:
# Interpolation Search:
# Index = 6
# Probes = 1
#
# Binary Search:
# Index = 6
# Probes = 4
